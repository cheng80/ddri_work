# %% [markdown]
# # HMW4 최종 정리 서비스 기획
#
# 이 노트북은 최종 결과를 빠르게 검토하고, 앱/웹 방향을 요약하는 챕터입니다.

# %%
from pathlib import Path
import pandas as pd

DATA_DIR = Path("../Data")
REPORT_DIR = Path("../reports")

# %% [markdown]
# ## 1. 모델 메타 정보

# %%
import json
meta = json.loads((DATA_DIR / "station_hour_model_meta.json").read_text(encoding="utf-8"))
meta

# %% [markdown]
# ## 2. 최종 리포트 요약

# %%
print((DATA_DIR / "station_hour_model_report.md").read_text(encoding="utf-8"))

# %% [markdown]
# ## 3. cluster 확장 리포트 요약

# %%
print((REPORT_DIR / "station_hour_cluster_augmented_report.md").read_text(encoding="utf-8"))

# %% [markdown]
# ## 4. 앱/웹 기획용 핵심 station

# %%
selected_rep = pd.read_csv(DATA_DIR / "station_hour_selected_representative_stations.csv", encoding="utf-8-sig")
selected_rep.groupby("cluster_name")[["station_name", "rental_total_2025", "mean_abs_error"]].head(3)
