# %%
from pathlib import Path

import branca.colormap as cm
import folium
import pandas as pd
import numpy as np
from folium.plugins import HeatMap
from IPython.display import display

PROJECT_ROOT = Path.cwd().parents[1]
STATION_PATH = PROJECT_ROOT / "works" / "01_clustering" / "08_integrated" / "source_data" / "ddri_common_station_master.csv"

# %%
FEATURE_PATH = PROJECT_ROOT / "hmw" / "Data" / "2023_아침" / "2023_morning.csv"
OUTPUT_HTML_PATH = PROJECT_ROOT / "hmw" / "Data" / "ddri_morning_map.html"


def build_folium_map() -> None:

    feature_df = pd.read_csv(FEATURE_PATH)
    station_df = pd.read_csv(STATION_PATH).rename(
        columns={"대여소번호": "station_id", "대여소명": "station_name", "위도": "lat", "경도": "lon"}
    )

    plot_df = feature_df.merge(
        station_df[["station_id", "station_name", "lat", "lon"]],
        on="station_id",
        how="left"
    )

    plot_df = plot_df.dropna(subset=["lat", "lon", "count"]).copy()

    center_lat = plot_df["lat"].mean()
    center_lon = plot_df["lon"].mean()

    fmap = folium.Map(
        location=[center_lat, center_lon],
        zoom_start=13,
        tiles="CartoDB positron"
    )

    station_layer = folium.FeatureGroup(name="대여소", show=True)
    heat_layer = folium.FeatureGroup(name="HeatMap", show=True)

    # 컬러맵 생성
    min_val = plot_df["count"].min()
    max_val = plot_df["count"].max()

    colormap = cm.LinearColormap(
        colors=["#2c7bb6", "#abd9e9", "#ffffbf", "#fdae61", "#d7191c"],
        vmin=min_val,
        vmax=max_val
    )

    colormap.caption = "반납횟수"

    # 대여소 점 표시
    for _, row in plot_df.iterrows():

        radius = max(((row["count"])**0.5) * 0.2, 3)

        folium.CircleMarker(
            location=[row["lat"], row["lon"]],
            radius=radius,
            color="white",
            weight=0.8,
            fill=True,
            fill_color=colormap(row["count"]),
            fill_opacity=0.85,
            popup=folium.Popup(
                f"""
                <b>대여소명</b>: {row['station_name']}<br>
                <b>반납횟수</b>: {row['count']:.2f}
                """,
                max_width=260
            ),
            tooltip=f"{row['station_name']} / 반납횟수 {row['count']:.1f}"
        ).add_to(station_layer)

    # HeatMap
    heat_data = plot_df[["lat", "lon", "count"]].values.tolist()

    HeatMap(
        heat_data,
        radius=20,
        blur=16,
        min_opacity=0.3,
        max_zoom=16
    ).add_to(heat_layer)

    station_layer.add_to(fmap)
    heat_layer.add_to(fmap)

    colormap.add_to(fmap)

    # 범례
    legend_html = """
    <div style="
        position: fixed;
        bottom: 30px;
        left: 30px;
        width: 230px;
        z-index: 9999;
        background: white;
        border: 2px solid #cbd5e1;
        border-radius: 8px;
        padding: 12px;
        font-size: 13px;
    ">
        <b>범례</b><br>
        색상 : 반납횟수<br>
        파랑 → 적음<br>
        빨강 → 많음<br>
        점 크기 = 반납횟수
    </div>
    """

    fmap.get_root().html.add_child(folium.Element(legend_html))

    # 제목
    title_html = """
    <div style="
        position: fixed;
        top: 15px;
        left: 50%;
        transform: translateX(-50%);
        z-index: 9999;
        background: white;
        padding: 10px 18px;
        border-radius: 10px;
        border: 1px solid #cbd5e1;
        font-size: 18px;
        font-weight: 700;
    ">
        2023년 아침 강남구 따릉이 반납 지도
    </div>
    """

    fmap.get_root().html.add_child(folium.Element(title_html))

    folium.LayerControl(collapsed=False).add_to(fmap)

    OUTPUT_HTML_PATH.parent.mkdir(parents=True, exist_ok=True)
    fmap.save(OUTPUT_HTML_PATH)

    display(fmap)


if __name__ == "__main__":
    build_folium_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d5c67a711d1ec0f20d23e20a2951fc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 30px;
#         left: 30px;
#         width: 230px;
#         z-index: 9999;
#         background: white;
#         border: 2px solid #cbd5e1;
#         border-radius: 8px;
#         padding: 12px;
#         font-size: 13px;
#     &quot;&gt;
#         &lt;b&gt;범례&lt;/b&gt;&lt;br&gt;
#         색상 : 반납횟수&lt;br&gt;
#         파랑 → 적음&lt;br&gt;
#         빨강 → 많음&lt;br&gt;
#         점 크기 = 반납횟수
#     &lt;/div&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         top: 15px;
#         left: 50%;
#         transform: translateX(-50%);
#         z-index: 9999;
#         background: white;
#         padding: 10px 18px;
#         border-radius: 10px;
#         border: 1px solid #cbd5e1;
#         font-size: 18px;
#         font-weight: 700;
#     &quot;&gt;
#         2023년 아침 강남구 따릉이 반납 지도
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d5c67a711d1ec0f20d23e20a2951fc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d5c67a711d1ec0f20d23e20a2951fc8 = L.map(
#                 &quot;map_2d5c67a711d1ec0f20d23e20a2951fc8&quot;,
#                 {
#                     center: [37.499219382621945, 127.05756136280492],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc080caf9d39a623aa844186a9655fd5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc080caf9d39a623aa844186a9655fd5.addTo(map_2d5c67a711d1ec0f20d23e20a2951fc8);
#
#
#             var feature_group_5107260948927b9b9f43ad0326d573c8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_20b961fb68065dc2bdc48e8a7101caa0 = L.circleMarker(
#                 [37.50723267, 127.05685425],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d7191cff&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.151583952922675, &quot;stroke&quot;: true, &quot;weight&quot;: 0.8}
#             ).addTo(feature_group_5107260948927b9b9f43ad0326d573c8);
#
#
#         var popup_c33c5e112fd33214b66af8c82a8317f9 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_5bdd48c8cb8d71924a604f539f4c52fe = $(`&lt;div id=&quot;html_5bdd48c8cb8d71924a604f539f4c52fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;b&gt;대여소명&lt;/b&gt;:  포스코사거리(기업은행)&lt;br&gt;                 &lt;b&gt;반납횟수&lt;/b&gt;: 8237.00                 &lt;/div&gt;`)[0];
#                 popup_c33c5e112fd33214b66af8c82a8317f9.setContent(html_5bdd48c8cb8d71924a604f539f4c52fe);
#
#
#
#         circle_marker_20b961fb68065dc2bdc48e8a7101caa0.bindPopup(popup_c33c5e112fd33214b66af8c82a8317f9)
#         ;
#
#
#
#
#             circle_marker_20b961fb68065dc2bdc48e8a7101caa0.bindTooltip(
#                 `&lt;div&gt;
#                       포스코사거리(기업은행) / 반납횟수 8237.0
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_e13f981ca86b73675442dbc8ca563d5c = L.circleMarker(
#                 [37.48735046, 127.10232544],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f2824cff&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 16.47543626129518, &quot;stroke&quot;: true, &quot;weight&quot;: 0.8}
#             ).addTo(feature_group_5107260948927b9b9f43ad0326d573c8);
#
#
#         var popup_297092119ee6d2478cef5283af40438a = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var

# %%
FEATURE_PATH = PROJECT_ROOT / "hmw" / "Data" / "2023_점심" / "2023_lunch.csv"
OUTPUT_HTML_PATH = PROJECT_ROOT / "hmw" / "Data" / "ddri_lunch_map.html"


def build_folium_map() -> None:

    feature_df = pd.read_csv(FEATURE_PATH)
    station_df = pd.read_csv(STATION_PATH).rename(
        columns={"대여소번호": "station_id", "대여소명": "station_name", "위도": "lat", "경도": "lon"}
    )

    plot_df = feature_df.merge(
        station_df[["station_id", "station_name", "lat", "lon"]],
        on="station_id",
        how="left"
    )

    plot_df = plot_df.dropna(subset=["lat", "lon", "count"]).copy()

    center_lat = plot_df["lat"].mean()
    center_lon = plot_df["lon"].mean()

    fmap = folium.Map(
        location=[center_lat, center_lon],
        zoom_start=13,
        tiles="CartoDB positron"
    )

    station_layer = folium.FeatureGroup(name="대여소", show=True)
    heat_layer = folium.FeatureGroup(name="HeatMap", show=True)

    # 컬러맵 생성
    min_val = plot_df["count"].min()
    max_val = plot_df["count"].max()

    colormap = cm.LinearColormap(
        colors=["#2c7bb6", "#abd9e9", "#ffffbf", "#fdae61", "#d7191c"],
        vmin=min_val,
        vmax=max_val
    )

    colormap.caption = "반납횟수"

    # 대여소 점 표시
    for _, row in plot_df.iterrows():

        radius = max(((row["count"])**0.5) * 0.2, 3)

        folium.CircleMarker(
            location=[row["lat"], row["lon"]],
            radius=radius,
            color="white",
            weight=0.8,
            fill=True,
            fill_color=colormap(row["count"]),
            fill_opacity=0.85,
            popup=folium.Popup(
                f"""
                <b>대여소명</b>: {row['station_name']}<br>
                <b>반납횟수</b>: {row['count']:.2f}
                """,
                max_width=260
            ),
            tooltip=f"{row['station_name']} / 반납횟수 {row['count']:.1f}"
        ).add_to(station_layer)

    # HeatMap
    heat_data = plot_df[["lat", "lon", "count"]].values.tolist()

    HeatMap(
        heat_data,
        radius=20,
        blur=16,
        min_opacity=0.3,
        max_zoom=16
    ).add_to(heat_layer)

    station_layer.add_to(fmap)
    heat_layer.add_to(fmap)

    colormap.add_to(fmap)

    # 범례
    legend_html = """
    <div style="
        position: fixed;
        bottom: 30px;
        left: 30px;
        width: 230px;
        z-index: 9999;
        background: white;
        border: 2px solid #cbd5e1;
        border-radius: 8px;
        padding: 12px;
        font-size: 13px;
    ">
        <b>범례</b><br>
        색상 : 반납횟수<br>
        파랑 → 적음<br>
        빨강 → 많음<br>
        점 크기 = 반납횟수
    </div>
    """

    fmap.get_root().html.add_child(folium.Element(legend_html))

    # 제목
    title_html = """
    <div style="
        position: fixed;
        top: 15px;
        left: 50%;
        transform: translateX(-50%);
        z-index: 9999;
        background: white;
        padding: 10px 18px;
        border-radius: 10px;
        border: 1px solid #cbd5e1;
        font-size: 18px;
        font-weight: 700;
    ">
        2023년 점심 강남구 따릉이 반납 지도
    </div>
    """

    fmap.get_root().html.add_child(folium.Element(title_html))

    folium.LayerControl(collapsed=False).add_to(fmap)

    OUTPUT_HTML_PATH.parent.mkdir(parents=True, exist_ok=True)
    fmap.save(OUTPUT_HTML_PATH)

    display(fmap)


if __name__ == "__main__":
    build_folium_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05bf9a94329107bfc184cba2293dd1a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 30px;
#         left: 30px;
#         width: 230px;
#         z-index: 9999;
#         background: white;
#         border: 2px solid #cbd5e1;
#         border-radius: 8px;
#         padding: 12px;
#         font-size: 13px;
#     &quot;&gt;
#         &lt;b&gt;범례&lt;/b&gt;&lt;br&gt;
#         색상 : 반납횟수&lt;br&gt;
#         파랑 → 적음&lt;br&gt;
#         빨강 → 많음&lt;br&gt;
#         점 크기 = 반납횟수
#     &lt;/div&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         top: 15px;
#         left: 50%;
#         transform: translateX(-50%);
#         z-index: 9999;
#         background: white;
#         padding: 10px 18px;
#         border-radius: 10px;
#         border: 1px solid #cbd5e1;
#         font-size: 18px;
#         font-weight: 700;
#     &quot;&gt;
#         2023년 점심 강남구 따릉이 반납 지도
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05bf9a94329107bfc184cba2293dd1a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05bf9a94329107bfc184cba2293dd1a7 = L.map(
#                 &quot;map_05bf9a94329107bfc184cba2293dd1a7&quot;,
#                 {
#                     center: [37.499219382621945, 127.05756136280489],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7056987cfbfa2bfa7de492d9e5695f9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b7056987cfbfa2bfa7de492d9e5695f9.addTo(map_05bf9a94329107bfc184cba2293dd1a7);
#
#
#             var feature_group_8100211badadaf33d66efeb5b4839c11 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_13e57cfbf3688a2c96576c2550c99c04 = L.circleMarker(
#                 [37.48897171, 127.05182648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d7191cff&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.229369482035537, &quot;stroke&quot;: true, &quot;weight&quot;: 0.8}
#             ).addTo(feature_group_8100211badadaf33d66efeb5b4839c11);
#
#
#         var popup_14c9ca200ae1af2585dd40006432d4cc = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_c47981753dfdf7b0864b441d169163e1 = $(`&lt;div id=&quot;html_c47981753dfdf7b0864b441d169163e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;b&gt;대여소명&lt;/b&gt;:  도곡역 아카데미스위트 앞&lt;br&gt;                 &lt;b&gt;반납횟수&lt;/b&gt;: 2616.00                 &lt;/div&gt;`)[0];
#                 popup_14c9ca200ae1af2585dd40006432d4cc.setContent(html_c47981753dfdf7b0864b441d169163e1);
#
#
#
#         circle_marker_13e57cfbf3688a2c96576c2550c99c04.bindPopup(popup_14c9ca200ae1af2585dd40006432d4cc)
#         ;
#
#
#
#
#             circle_marker_13e57cfbf3688a2c96576c2550c99c04.bindTooltip(
#                 `&lt;div&gt;
#                       도곡역 아카데미스위트 앞 / 반납횟수 2616.0
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_4a3aba043e1210790f59dc563afc3d84 = L.circleMarker(
#                 [37.50400925, 127.0490799],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#df3629ff&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.97997995989972, &quot;stroke&quot;: true, &quot;weight&quot;: 0.8}
#             ).addTo(feature_group_8100211badadaf33d66efeb5b4839c11);
#
#
#         var popup_ab4c693af4df9c777478cfe959457791 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var

# %%
FEATURE_PATH = PROJECT_ROOT / "hmw" / "Data" / "2023_저녁" / "2023_evening.csv"
OUTPUT_HTML_PATH = PROJECT_ROOT / "hmw" / "Data" / "ddri_evening_map.html"


def build_folium_map() -> None:

    feature_df = pd.read_csv(FEATURE_PATH)
    station_df = pd.read_csv(STATION_PATH).rename(
        columns={"대여소번호": "station_id", "대여소명": "station_name", "위도": "lat", "경도": "lon"}
    )

    plot_df = feature_df.merge(
        station_df[["station_id", "station_name", "lat", "lon"]],
        on="station_id",
        how="left"
    )

    plot_df = plot_df.dropna(subset=["lat", "lon", "count"]).copy()

    center_lat = plot_df["lat"].mean()
    center_lon = plot_df["lon"].mean()

    fmap = folium.Map(
        location=[center_lat, center_lon],
        zoom_start=13,
        tiles="CartoDB positron"
    )

    station_layer = folium.FeatureGroup(name="대여소", show=True)
    heat_layer = folium.FeatureGroup(name="HeatMap", show=True)

    # 컬러맵 생성
    min_val = plot_df["count"].min()
    max_val = plot_df["count"].max()

    colormap = cm.LinearColormap(
        colors=["#2c7bb6", "#abd9e9", "#ffffbf", "#fdae61", "#d7191c"],
        vmin=min_val,
        vmax=max_val
    )

    colormap.caption = "반납횟수"

    # 대여소 점 표시
    for _, row in plot_df.iterrows():

        radius = max(((row["count"])**0.5) * 0.2, 3)

        folium.CircleMarker(
            location=[row["lat"], row["lon"]],
            radius=radius,
            color="white",
            weight=0.8,
            fill=True,
            fill_color=colormap(row["count"]),
            fill_opacity=0.85,
            popup=folium.Popup(
                f"""
                <b>대여소명</b>: {row['station_name']}<br>
                <b>반납횟수</b>: {row['count']:.2f}
                """,
                max_width=260
            ),
            tooltip=f"{row['station_name']} / 반납횟수 {row['count']:.1f}"
        ).add_to(station_layer)

    # HeatMap
    heat_data = plot_df[["lat", "lon", "count"]].values.tolist()

    HeatMap(
        heat_data,
        radius=20,
        blur=16,
        min_opacity=0.3,
        max_zoom=16
    ).add_to(heat_layer)

    station_layer.add_to(fmap)
    heat_layer.add_to(fmap)

    colormap.add_to(fmap)

    # 범례
    legend_html = """
    <div style="
        position: fixed;
        bottom: 30px;
        left: 30px;
        width: 230px;
        z-index: 9999;
        background: white;
        border: 2px solid #cbd5e1;
        border-radius: 8px;
        padding: 12px;
        font-size: 13px;
    ">
        <b>범례</b><br>
        색상 : 반납횟수<br>
        파랑 → 적음<br>
        빨강 → 많음<br>
        점 크기 = 반납횟수
    </div>
    """

    fmap.get_root().html.add_child(folium.Element(legend_html))

    # 제목
    title_html = """
    <div style="
        position: fixed;
        top: 15px;
        left: 50%;
        transform: translateX(-50%);
        z-index: 9999;
        background: white;
        padding: 10px 18px;
        border-radius: 10px;
        border: 1px solid #cbd5e1;
        font-size: 18px;
        font-weight: 700;
    ">
        2023년 저녁 강남구 따릉이 반납 지도
    </div>
    """

    fmap.get_root().html.add_child(folium.Element(title_html))

    folium.LayerControl(collapsed=False).add_to(fmap)

    OUTPUT_HTML_PATH.parent.mkdir(parents=True, exist_ok=True)
    fmap.save(OUTPUT_HTML_PATH)

    display(fmap)


if __name__ == "__main__":
    build_folium_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f315eba4f500da364d4c0868f23af883 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 30px;
#         left: 30px;
#         width: 230px;
#         z-index: 9999;
#         background: white;
#         border: 2px solid #cbd5e1;
#         border-radius: 8px;
#         padding: 12px;
#         font-size: 13px;
#     &quot;&gt;
#         &lt;b&gt;범례&lt;/b&gt;&lt;br&gt;
#         색상 : 반납횟수&lt;br&gt;
#         파랑 → 적음&lt;br&gt;
#         빨강 → 많음&lt;br&gt;
#         점 크기 = 반납횟수
#     &lt;/div&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         top: 15px;
#         left: 50%;
#         transform: translateX(-50%);
#         z-index: 9999;
#         background: white;
#         padding: 10px 18px;
#         border-radius: 10px;
#         border: 1px solid #cbd5e1;
#         font-size: 18px;
#         font-weight: 700;
#     &quot;&gt;
#         2023년 저녁 강남구 따릉이 반납 지도
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f315eba4f500da364d4c0868f23af883&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f315eba4f500da364d4c0868f23af883 = L.map(
#                 &quot;map_f315eba4f500da364d4c0868f23af883&quot;,
#                 {
#                     center: [37.49921938262195, 127.05756136280489],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6fa21739c3017cb63fe4b98aea17154 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e6fa21739c3017cb63fe4b98aea17154.addTo(map_f315eba4f500da364d4c0868f23af883);
#
#
#             var feature_group_455b6a0017a9e286217fc4d34d5bc080 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_e14bd7cdb4eb99fd3bc86a3aa8d1cbdf = L.circleMarker(
#                 [37.52407074, 127.02178955],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fecc84ff&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.288205727444508, &quot;stroke&quot;: true, &quot;weight&quot;: 0.8}
#             ).addTo(feature_group_455b6a0017a9e286217fc4d34d5bc080);
#
#
#         var popup_a2fdcecd9ec0715c0e280569e6fb339a = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_c654bccc2950432216d3ff30544387cd = $(`&lt;div id=&quot;html_c654bccc2950432216d3ff30544387cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;b&gt;대여소명&lt;/b&gt;:  현대고등학교 건너편&lt;br&gt;                 &lt;b&gt;반납횟수&lt;/b&gt;: 3775.00                 &lt;/div&gt;`)[0];
#                 popup_a2fdcecd9ec0715c0e280569e6fb339a.setContent(html_c654bccc2950432216d3ff30544387cd);
#
#
#
#         circle_marker_e14bd7cdb4eb99fd3bc86a3aa8d1cbdf.bindPopup(popup_a2fdcecd9ec0715c0e280569e6fb339a)
#         ;
#
#
#
#
#             circle_marker_e14bd7cdb4eb99fd3bc86a3aa8d1cbdf.bindTooltip(
#                 `&lt;div&gt;
#                       현대고등학교 건너편 / 반납횟수 3775.0
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_d41b1537f66201e29866d1dd454050fc = L.circleMarker(
#                 [37.5055809, 127.02427673],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#dcefd1ff&quot;, &quot;fillOpacity&quot;: 0.85, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.524704719832526, &quot;stroke&quot;: true, &quot;weight&quot;: 0.8}
#             ).addTo(feature_group_455b6a0017a9e286217fc4d34d5bc080);
#
#
#         var popup_d04797ea9c4437f97e8dc2b2ad6cc433 = L.popup({
#   &quot;maxWidth&quot;: 260,
# });
#
#
#
#                 var html_6

# %%
# for i in range(1,13):
#     FEATURE_PATH = PROJECT_ROOT / "works" / "01_clustering" / "06_data" / "2023_저녁" / f"df{i}_2023.csv"
#     OUTPUT_HTML_PATH = PROJECT_ROOT / "works" / "04_presentation" / "01_clustering" / "ddri_map_month.html"


#     def build_folium_map() -> None:

#         feature_df = pd.read_csv(FEATURE_PATH)
#         station_df = pd.read_csv(STATION_PATH).rename(
#             columns={"대여소번호": "station_id", "대여소명": "station_name", "위도": "lat", "경도": "lon"}
#         )

#         plot_df = feature_df.merge(
#             station_df[["station_id", "station_name", "lat", "lon"]],
#             on="station_id",
#             how="left"
#         )

#         plot_df = plot_df.dropna(subset=["lat", "lon", "count"]).copy()

#         center_lat = plot_df["lat"].mean()
#         center_lon = plot_df["lon"].mean()

#         fmap = folium.Map(
#             location=[center_lat, center_lon],
#             zoom_start=13,
#             tiles="CartoDB positron"
#         )

#         station_layer = folium.FeatureGroup(name="대여소", show=True)
#         heat_layer = folium.FeatureGroup(name="HeatMap", show=True)

#         # 컬러맵 생성
#         min_val = plot_df["count"].min()
#         max_val = plot_df["count"].max()

#         colormap = cm.LinearColormap(
#             colors=["#2c7bb6", "#abd9e9", "#ffffbf", "#fdae61", "#d7191c"],
#             vmin=min_val,
#             vmax=max_val
#         )

#         colormap.caption = "반납횟수"

#         # 대여소 점 표시
#         for _, row in plot_df.iterrows():

#             radius = max((row["count"] ** 0.5) * 1.2, 3)

#             folium.CircleMarker(
#                 location=[row["lat"], row["lon"]],
#                 radius=radius,
#                 color="white",
#                 weight=0.8,
#                 fill=True,
#                 fill_color=colormap(row["count"]),
#                 fill_opacity=0.85,
#                 popup=folium.Popup(
#                     f"""
#                     <b>대여소명</b>: {row['station_name']}<br>
#                     <b>반납횟수</b>: {row['count']:.2f}
#                     """,
#                     max_width=260
#                 ),
#                 tooltip=f"{row['station_name']} / 반납횟수 {row['count']:.1f}"
#             ).add_to(station_layer)

#         # HeatMap
#         heat_data = plot_df[["lat", "lon", "count"]].values.tolist()

#         HeatMap(
#             heat_data,
#             radius=20,
#             blur=16,
#             min_opacity=0.3,
#             max_zoom=16
#         ).add_to(heat_layer)

#         station_layer.add_to(fmap)
#         heat_layer.add_to(fmap)

#         colormap.add_to(fmap)

#         # 범례
#         legend_html = """
#         <div style="
#             position: fixed;
#             bottom: 30px;
#             left: 30px;
#             width: 230px;
#             z-index: 9999;
#             background: white;
#             border: 2px solid #cbd5e1;
#             border-radius: 8px;
#             padding: 12px;
#             font-size: 13px;
#         ">
#             <b>범례</b><br>
#             색상 : 반납횟수<br>
#             파랑 → 적음<br>
#             빨강 → 많음<br>
#             점 크기 = 반납횟수
#         </div>
#         """

#         fmap.get_root().html.add_child(folium.Element(legend_html))

#         # 제목
#         title_html = f"""
#         <div style="
#             position: fixed;
#             top: 15px;
#             left: 50%;
#             transform: translateX(-50%);
#             z-index: 9999;
#             background: white;
#             padding: 10px 18px;
#             border-radius: 10px;
#             border: 1px solid #cbd5e1;
#             font-size: 18px;
#             font-weight: 700;
#         ">
#             2023년 {i}월 저녁 강남구 따릉이 반납 지도
#         </div>
#         """

#         fmap.get_root().html.add_child(folium.Element(title_html))

#         folium.LayerControl(collapsed=False).add_to(fmap)

#         OUTPUT_HTML_PATH.parent.mkdir(parents=True, exist_ok=True)
#         fmap.save(OUTPUT_HTML_PATH)

#         display(fmap)


#     if __name__ == "__main__":
#         build_folium_map()
