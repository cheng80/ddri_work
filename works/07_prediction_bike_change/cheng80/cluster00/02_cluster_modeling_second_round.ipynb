# %% [markdown]
# # cluster00 bike_change 2차 피처 조합 비교
#
# ## 용어 설명
#
# - `business mixed pattern`(업무/상업 리듬): 야간, 주말, 휴일 전날처럼 주거형 리듬을 나타내는 피처 축
# - `location`(입지 피처): 표고, 버스정류장 수처럼 위치 특성을 나타내는 피처 축
#
# 목표:
# - `cluster00`에서 경량 피처 조합이 `bike_change`에도 유지 가능한지 확인한다.

# %%
from pathlib import Path

import pandas as pd
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

ROOT = Path('/Users/cheng80/Desktop/ddri_work')
WORK_DIR = ROOT / 'works/07_prediction_bike_change'
TRAIN_PATH = WORK_DIR / 'output/data/ddri_prediction_bike_change_train_2023_2024.csv'
TEST_PATH = WORK_DIR / 'output/data/ddri_prediction_bike_change_test_2025.csv'
OUTPUT_DIR = WORK_DIR / 'output/data'

TARGET_CLUSTER = 0
TARGET_STATION_GROUP = '업무/상업 혼합형'
RANDOM_STATE = 42

# %%
FULL_FEATURES = [
    'station_id', 'cluster', 'mapped_dong_code', 'hour', 'weekday', 'month', 'holiday',
    'temperature', 'humidity', 'precipitation', 'wind_speed',
    'lag_1h', 'lag_24h', 'lag_168h', 'rolling_mean_24h', 'rolling_std_24h',
    'rolling_mean_168h', 'rolling_std_168h', 'rolling_mean_6h',
    'is_weekend', 'is_night_hour', 'is_commute_hour', 'hour_sin', 'is_rainy', 'hour_cos',
    'commute_morning_flag', 'commute_evening_flag',
    'subway_distance_m', 'distance_naturepark_m', 'restaurant_count_300m',
    'convenience_store_count_300m', 'bus_stop_count_300m', 'cafe_count_300m',
    'elevation_diff_nearest_subway_m', 'nearest_park_area_sqm'
]

FEATURE_SETS = {
    'full_36': FULL_FEATURES,
    'subset_a_business_transit_core': [
        'station_id', 'cluster', 'mapped_dong_code', 'hour', 'weekday', 'month', 'holiday',
        'lag_1h', 'lag_24h', 'rolling_mean_24h', 'rolling_std_24h', 'rolling_mean_6h',
        'is_commute_hour', 'commute_morning_flag', 'commute_evening_flag',
        'subway_distance_m', 'bus_stop_count_300m', 'restaurant_count_300m', 'cafe_count_300m'
    ],
    'subset_b_business_transit_weather': [
        'station_id', 'cluster', 'mapped_dong_code', 'hour', 'weekday', 'month', 'holiday',
        'temperature', 'humidity', 'precipitation', 'wind_speed', 'is_rainy',
        'lag_1h', 'lag_24h', 'rolling_mean_24h', 'rolling_mean_6h',
        'is_commute_hour', 'commute_morning_flag', 'commute_evening_flag',
        'subway_distance_m', 'bus_stop_count_300m'
    ],
    'subset_c_business_location': [
        'station_id', 'cluster', 'mapped_dong_code', 'hour', 'weekday', 'month', 'holiday',
        'lag_1h', 'lag_24h', 'rolling_mean_24h', 'rolling_mean_6h',
        'subway_distance_m', 'distance_naturepark_m', 'restaurant_count_300m',
        'convenience_store_count_300m', 'bus_stop_count_300m', 'cafe_count_300m',
        'elevation_diff_nearest_subway_m', 'nearest_park_area_sqm'
    ],
    'subset_d_current_compact': [
        'station_id', 'cluster', 'mapped_dong_code', 'hour', 'weekday', 'month', 'holiday',
        'temperature', 'precipitation', 'lag_1h', 'lag_24h', 'rolling_mean_24h',
        'rolling_std_24h', 'rolling_mean_6h', 'subway_distance_m', 'bus_stop_count_300m',
        'restaurant_count_300m', 'cafe_count_300m', 'is_commute_hour',
        'commute_morning_flag', 'commute_evening_flag', 'is_rainy'
    ]
}

# %%
train_raw = pd.read_csv(TRAIN_PATH)
test_raw = pd.read_csv(TEST_PATH)

train_group = train_raw.loc[train_raw['cluster'] == TARGET_CLUSTER].copy()
test_group = test_raw.loc[test_raw['cluster'] == TARGET_CLUSTER].copy()

train_2023 = train_group.loc[train_group['date'] < '2024-01-01'].copy()
valid_2024 = train_group.loc[train_group['date'] >= '2024-01-01'].copy()
test_2025 = test_group.copy()
full_train = train_group.copy()

# %%
BASE_CATEGORICAL = ['station_id', 'cluster', 'mapped_dong_code', 'hour', 'weekday', 'month', 'holiday']

def evaluate_predictions(model_name: str, split_name: str, y_true: pd.Series, y_pred) -> dict:
    rmse = mean_squared_error(y_true, y_pred) ** 0.5
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    sign_accuracy = ((pd.Series(y_pred) >= 0) == (y_true.reset_index(drop=True) >= 0)).mean()
    return {
        'model': model_name,
        'split': split_name,
        'rmse': round(float(rmse), 4),
        'mae': round(float(mae), 4),
        'r2': round(float(r2), 4),
        'sign_accuracy': round(float(sign_accuracy), 4),
    }

def prepare_xy(df: pd.DataFrame, feature_cols: list[str]):
    X = df[feature_cols].copy()
    for col in [c for c in feature_cols if c in BASE_CATEGORICAL]:
        X[col] = X[col].astype('category')
    y = df['bike_change'].copy()
    return X, y

def build_lgbm_model() -> LGBMRegressor:
    return LGBMRegressor(
        objective='regression',
        learning_rate=0.05,
        n_estimators=400,
        num_leaves=31,
        subsample=0.9,
        colsample_bytree=0.9,
        random_state=RANDOM_STATE,
        verbose=-1,
    )

# %%
results = []

for feature_set_name, feature_cols in FEATURE_SETS.items():
    X_train, y_train = prepare_xy(train_2023, feature_cols)
    X_valid, y_valid = prepare_xy(valid_2024, feature_cols)
    X_full, y_full = prepare_xy(full_train, feature_cols)
    X_test, y_test = prepare_xy(test_2025, feature_cols)

    cat_cols = [c for c in feature_cols if c in BASE_CATEGORICAL]
    model = build_lgbm_model()
    model.fit(X_train, y_train, categorical_feature=cat_cols)
    results.append(evaluate_predictions(feature_set_name, 'train_2023', y_train, model.predict(X_train)))
    results.append(evaluate_predictions(feature_set_name, 'validation_2024', y_valid, model.predict(X_valid)))

    model = build_lgbm_model()
    model.fit(X_full, y_full, categorical_feature=cat_cols)
    results.append(evaluate_predictions(feature_set_name, 'train_full_refit', y_full, model.predict(X_full)))
    results.append(evaluate_predictions(feature_set_name, 'test_2025_refit', y_test, model.predict(X_test)))

results_df = pd.DataFrame(results)
results_df['cluster'] = TARGET_CLUSTER
results_df['station_group'] = TARGET_STATION_GROUP
results_df['feature_count'] = results_df['model'].map({k: len(v) for k, v in FEATURE_SETS.items()})

metrics_path = OUTPUT_DIR / 'ddri_bike_change_cluster00_second_round_metrics.csv'
results_df.to_csv(metrics_path, index=False, encoding='utf-8-sig')
print('saved:', metrics_path)
results_df
# Out:
# saved: /Users/cheng80/Desktop/ddri_work/works/07_prediction_bike_change/output/data/ddri_bike_change_cluster00_second_round_metrics.csv
#                                 model             split    rmse     mae  \
# 0                             full_36        train_2023  0.7344  0.5101
# 1                             full_36   validation_2024  0.8966  0.6043
# 2                             full_36  train_full_refit  0.7842  0.5406
# 3                             full_36   test_2025_refit  1.0852  0.6181
# 4      subset_a_business_transit_core        train_2023  0.7888  0.5446
# 5      subset_a_business_transit_core   validation_2024  0.9066  0.6143
# 6      subset_a_business_transit_core  train_full_refit  0.8217  0.5659
# 7      subset_a_business_transit_core   test_2025_refit  1.1225  0.6223
# 8   subset_b_business_transit_weather        train_2023  0.7565  0.5205
# 9   subset_b_business_transit_weather   validation_2024  0.9070  0.6096
# 10  subset_b_business_transit_weather  train_full_refit  0.8017  0.5487
# 11  subset_b_business_transit_weather   test_2025_refit  1.1373  0.6605
# 12         subset_c_business_location        train_2023  0.8029  0.5518
# 13         subset_c_business_location   validation_2024  0.9071  0.6135
# 14         subset_c_business_location  train_full_refit  0.8336  0.5708
# 15         subset_c_business_location   test_2025_refit  1.1161  0.6249
# 16           subset_d_current_compact        train_2023  0.7655  0.5268
# 17           subset_d_current_compact   validation_2024  0.9064  0.6114
# 18           subset_d_current_compact  train_full_refit  0.8089  0.5528
# 19           subset_d_current_compact   test_2025_refit  1.1579  0.6544
#
#         r2  sign_accuracy  cluster station_group  feature_count
# 0   0.6929         0.9076        0     업무/상업 혼합형             35
# 1   0.4515         0.8837        0     업무/상업 혼합형             35
# 2   0.6179         0.8977        0     업무/상업 혼합형             35
# 3   0.2806         0.9091        0     업무/상업 혼합형             35
# 4   0.6458         0.9071        0     업무/상업 혼합형             19
# 5   0.4392         0.8842        0     업무/상업 혼합형             19
# 6   0.5805         0.8968        0     업무/상업 혼합형             19
# 7   0.2303         0.9041        0     업무/상업 혼합형             19
# 8   0.6743         0.9044        0     업무/상업 혼합형             21
# 9   0.4386         0.8815        0     업무/상업 혼합형             21
# 10  0.6007         0.8925        0     업무/상업 혼합형             21
# 11  0.2098         0.9022        0     업무/상업 혼합형             21
# 12  0.6330         0.9051        0     업무/상업 혼합형             19
# 13  0.4385         0.8836        0     업무/상업 혼합형             19
# 14  0.5682         0.8957        0     업무/상업 혼합형             19
# 15  0.2390         0.9029        0     업무/상업 혼합형             19
# 16  0.6664         0.8986        0     업무/상업 혼합형             22
# 17  0.4394         0.8785        0     업무/상업 혼합형             22
# 18  0.5935         0.8941        0     업무/상업 혼합형             22
# 19  0.1810         0.9007        0     업무/상업 혼합형             22

# %%
results_df[results_df['split'] == 'test_2025_refit'].sort_values('rmse').reset_index(drop=True)
# Out:
#                                model            split    rmse     mae      r2  \
# 0                            full_36  test_2025_refit  1.0852  0.6181  0.2806
# 1         subset_c_business_location  test_2025_refit  1.1161  0.6249  0.2390
# 2     subset_a_business_transit_core  test_2025_refit  1.1225  0.6223  0.2303
# 3  subset_b_business_transit_weather  test_2025_refit  1.1373  0.6605  0.2098
# 4           subset_d_current_compact  test_2025_refit  1.1579  0.6544  0.1810
#
#    sign_accuracy  cluster station_group  feature_count
# 0         0.9091        0     업무/상업 혼합형             35
# 1         0.9029        0     업무/상업 혼합형             19
# 2         0.9041        0     업무/상업 혼합형             19
# 3         0.9022        0     업무/상업 혼합형             21
# 4         0.9007        0     업무/상업 혼합형             22
